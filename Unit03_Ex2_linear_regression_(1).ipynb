# %% [markdown]
# <a href="https://colab.research.google.com/github/Sosswood/Machine-Learning/blob/main/Unit03_Ex2_linear_regression_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from scipy import stats

#Create the arrays that represent the values of the x and y axis
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

#Execute a method that returns some important key values of Linear Regression
slope, intercept, r, p, std_err = stats.linregress(x, y)

# measure the correlation
corr, _ = stats.pearsonr(x, y)
print('Pearsons correlation: %.3f' % corr)

#Create a function that uses the slope and intercept values to return a new value.
#This new value represents where on the y-axis the corresponding x value will be placed
def myfunc(x):
  return slope * x + intercept

#Run each value of the x array through the function. This will result in a new array with new values for the y-axis
mymodel = list(map(myfunc, x))

#Draw the original scatter plot & the line of linear regression
plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()
# Out:
# Pearsons correlation: -0.759

# %% [markdown]
# ## Predict Future Values

# %%
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return intercept + slope * x

speed = myfunc(10)

print(speed)
# Out:
# 85.59308314937454

# %% [markdown]
# ![img_linear_regression2.png](attachment:img_linear_regression2.png)

# %% [markdown]
# If x=10 then predicted y is 85.59

# %%
import matplotlib.pyplot as plt
from scipy import stats

# The primary variables you can change are the 'x' and 'y' arrays.
# These define the dataset for which the linear regression is calculated.

# Example of changing 'x' and 'y':
# x = [1, 2, 3, 4, 5]
# y = [2, 4, 5, 4, 5]

# You can also change the value used for prediction, for example,
# when calling myfunc. In the previous cell, it was myfunc(10).
# You can change '10' to any other desired x-value for prediction.
# For instance, to predict for x=15:
# predicted_y = myfunc(15)
# print(predicted_y)

# %%
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return intercept + slope * x

speed = myfunc(15)

print(speed)
# Out:
# 76.83664459161147

# %%
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return intercept + slope * x

speed = myfunc(5)

print(speed)
# Out:
# 94.3495217071376

# %%
import matplotlib.pyplot as plt
from scipy import stats

#Create the arrays that represent the values of the x and y axis
x = [5,7,8,7,2,12,2,9,3,11,12,25,6]
y = [99,86,92,88,111,10,105,87,94,84,95,85,86]

#Execute a method that returns some important key values of Linear Regression
slope, intercept, r, p, std_err = stats.linregress(x, y)

# measure the correlation
corr, _ = stats.pearsonr(x, y)
print('Pearsons correlation: %.3f' % corr)

#Create a function that uses the slope and intercept values to return a new value.
#This new value represents where on the y-axis the corresponding x value will be placed
def myfunc(x):
  return slope * x + intercept

#Run each value of the x array through the function. This will result in a new array with new values for the y-axis
mymodel = list(map(myfunc, x))

#Draw the original scatter plot & the line of linear regression
plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()
# Out:
# Pearsons correlation: -0.359

# %%
from scipy import stats

x = [5,7,8,7,2,12,2,9,3,11,12,25,6]
y = [99,86,92,88,111,10,105,87,94,84,95,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return intercept + slope * x

speed = myfunc(10)

print(speed)
# Out:
# 83.97645622602023

# %%
from scipy import stats

x = [5,7,8,7,2,12,2,9,3,11,12,25,6]
y = [99,86,92,88,111,10,105,87,94,84,95,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return intercept + slope * x

speed = myfunc(15)

print(speed)
# Out:
# 76.76072549703522

# %%
from scipy import stats

x = [5,7,8,7,2,12,2,9,3,11,12,25,6]
y = [99,86,92,88,111,10,105,87,94,84,95,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return intercept + slope * x

speed = myfunc(5)

print(speed)
# Out:
# 91.19218695500524
